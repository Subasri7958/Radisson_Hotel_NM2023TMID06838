# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('House Price India.csv')

# %%
import warnings

# %%
warnings.filterwarnings('ignore')

# %%
data.head()
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
# 3  6762812605  42491                   4                 2.50         3310
# 4  6762812919  42491                   3                 2.00         2710
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
# 3     42998               2.0                   0                0
# 4      4500               1.5                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# ...

# %%
data.tail()
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 14615  6762830250  42734                   2                  1.5
# 14616  6762830339  42734                   3                  2.0
# 14617  6762830618  42734                   2                  1.0
# 14618  6762830709  42734                   4                  1.0
# 14619  6762831463  42734                   3                  1.0
#
#        living area  lot area  number of floors  waterfront present  \
# 14615         1556     20000               1.0                   0
# 14616         1680      7000               1.5                   0
# 14617         1070      6120               1.0                   0
# 14618         1030      6621               1.0                   0
# 14619          900      4770               1.0                   0
#
#        number of views  condition of the house  ...  Built Year  \
# 14615                0                       4  ...        1957
# ...

# %%
data.shape
# Out:
# (14620, 23)

# %%
data.isnull().sum()
# Out:
# id                                       0
# Date                                     0
# number of bedrooms                       0
# number of bathrooms                      0
# living area                              0
# lot area                                 0
# number of floors                         0
# waterfront present                       0
# number of views                          0
# condition of the house                   0
# grade of the house                       0
# Area of the house(excluding basement)    0
# Area of the basement                     0
# Built Year                               0
# Renovation Year                          0
# Postal Code                              0
# Lattitude                                0
# Longitude                                0
# living_area_renov                        0
# lot_area_renov                           0
# Number of schools nearby                 0
# Distance from the airport                0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14620 entries, 0 to 14619
# Data columns (total 23 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     14620 non-null  int64
#  1   Date                                   14620 non-null  int64
#  2   number of bedrooms                     14620 non-null  int64
#  3   number of bathrooms                    14620 non-null  float64
#  4   living area                            14620 non-null  int64
#  5   lot area                               14620 non-null  int64
#  6   number of floors                       14620 non-null  float64
#  7   waterfront present                     14620 non-null  int64
#  8   number of views                        14620 non-null  int64
#  9   condition of the house                 14620 non-null  int64
# ...

# %%
data.describe()
# Out:
#                  id          Date  number of bedrooms  number of bathrooms  \
# count  1.462000e+04  14620.000000        14620.000000         14620.000000
# mean   6.762821e+09  42604.538646            3.379343             2.129583
# std    6.237575e+03     67.347991            0.938719             0.769934
# min    6.762810e+09  42491.000000            1.000000             0.500000
# 25%    6.762815e+09  42546.000000            3.000000             1.750000
# 50%    6.762821e+09  42600.000000            3.000000             2.250000
# 75%    6.762826e+09  42662.000000            4.000000             2.500000
# max    6.762832e+09  42734.000000           33.000000             8.000000
#
#         living area      lot area  number of floors  waterfront present  \
# count  14620.000000  1.462000e+04      14620.000000        14620.000000
# mean    2098.262996  1.509328e+04          1.502360            0.007661
# std      928.275721  3.791962e+04          0.540239            0.087193
# ...

# %%
m=[]
n=[]
for column in data.columns:
    if data[column].nunique()>10:
        n.append(column)
    else:
        m.append(column)

# %%
m
# Out:
# ['number of floors',
#  'waterfront present',
#  'number of views',
#  'condition of the house',
#  'grade of the house',
#  'Number of schools nearby']

# %%
n
# Out:
# ['id',
#  'Date',
#  'number of bedrooms',
#  'number of bathrooms',
#  'living area',
#  'lot area',
#  'Area of the house(excluding basement)',
#  'Area of the basement',
#  'Built Year',
#  'Renovation Year',
#  'Postal Code',
#  'Lattitude',
#  'Longitude',
#  'living_area_renov',
#  'lot_area_renov',
#  'Distance from the airport',
#  'Price']

# %%
#univariate
sns.countplot(data=data, x='condition of the house')
# Out:
# <Axes: xlabel='condition of the house', ylabel='count'>

# %%
#bi-variate
sns.scatterplot(x='Distance from the airport', y='Date', data=data)
plt.title('Distance from the airport vs. Date')
# Out:
# Text(0.5, 1.0, 'Distance from the airport vs. Date')

# %%
sns.lineplot(x='Distance from the airport', y='Date', data=data)
# Out:
# <Axes: xlabel='Distance from the airport', ylabel='Date'>

# %%
#multi-variate
sns.jointplot(x='Distance from the airport', y='Distance from the airport',hue=data['living area'], data=data)

# %%
data.describe()
# Out:
#                  id          Date  number of bedrooms  number of bathrooms  \
# count  1.462000e+04  14620.000000        14620.000000         14620.000000
# mean   6.762821e+09  42604.538646            3.379343             2.129583
# std    6.237575e+03     67.347991            0.938719             0.769934
# min    6.762810e+09  42491.000000            1.000000             0.500000
# 25%    6.762815e+09  42546.000000            3.000000             1.750000
# 50%    6.762821e+09  42600.000000            3.000000             2.250000
# 75%    6.762826e+09  42662.000000            4.000000             2.500000
# max    6.762832e+09  42734.000000           33.000000             8.000000
#
#         living area      lot area  number of floors  waterfront present  \
# count  14620.000000  1.462000e+04      14620.000000        14620.000000
# mean    2098.262996  1.509328e+04          1.502360            0.007661
# std      928.275721  3.791962e+04          0.540239            0.087193
# ...

# %%
data['Date'].median()
# Out:
# 42600.0

# %%
data.corr()
# Out:
#                                              id      Date  number of bedrooms  \
# id                                     1.000000  0.045966           -0.329034
# Date                                   0.045966  1.000000           -0.015663
# number of bedrooms                    -0.329034 -0.015663            1.000000
# number of bathrooms                   -0.516909 -0.026485            0.509784
# living area                           -0.648127 -0.021958            0.570526
# lot area                              -0.100269  0.004392            0.034416
# number of floors                      -0.312305 -0.010335            0.177294
# waterfront present                    -0.112937  0.012006           -0.006257
# number of views                       -0.293004 -0.004782            0.078665
# condition of the house                -0.045061 -0.027402            0.026597
# grade of the house                    -0.673448 -0.033097            0.352945
# ...

# %%
#handling missing values
columns_with_missing = data.columns[data.isnull().any()]
data.dropna(subset=columns_with_missing, inplace=True)

for column in columns_with_missing:
    data[column].fillna(data[column].mean(), inplace=True)

from sklearn.impute import KNNImputer
imputer = KNNImputer(n_neighbors=5)
data_imputed = imputer.fit_transform(data)
data = pd.DataFrame(data_imputed, columns=data.columns)

for column in columns_with_missing:
    data[column + '_missing'] = data[column].isnull().astype(int)

remaining_missing = data.isnull().sum()

data.to_csv('cleaned_dataset.csv', index=False)

# %%
data
# Out:
#                  id     Date  number of bedrooms  number of bathrooms  \
# 0      6.762810e+09  42491.0                 5.0                 2.50
# 1      6.762811e+09  42491.0                 4.0                 2.50
# 2      6.762811e+09  42491.0                 5.0                 2.75
# 3      6.762813e+09  42491.0                 4.0                 2.50
# 4      6.762813e+09  42491.0                 3.0                 2.00
# ...             ...      ...                 ...                  ...
# 14615  6.762830e+09  42734.0                 2.0                 1.50
# 14616  6.762830e+09  42734.0                 3.0                 2.00
# 14617  6.762831e+09  42734.0                 2.0                 1.00
# 14618  6.762831e+09  42734.0                 4.0                 1.00
# 14619  6.762831e+09  42734.0                 3.0                 1.00
#
#        living area  lot area  number of floors  waterfront present  \
# ...
